# %%
# Load the TensorBoard notebook extension.
# %load_ext tensorboard

from datetime import datetime
from packaging import version
import tensorflow as tf
from tensorflow import keras
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import TensorBoard

print("TensorFlow version: ", tf.__version__)
assert version.parse(tf.__version__).release[0] >= 2, \
    "This notebook requires TensorFlow 2.0 or above."
# Out:
# TensorFlow version:  2.1.0

# %%
model = load_model('supercombo.keras')
# Out:
# WARNING:tensorflow:No training configuration found in save file: the model was *not* compiled. Compile it manually.

# %%
print(model.summary())
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# vision_input_imgs (InputLayer)  [(None, 12, 128, 256 0
# __________________________________________________________________________________________________
# vision_permute (Permute)        (None, 128, 256, 12) 0           vision_input_imgs[0][0]
# __________________________________________________________________________________________________
# vision_conv2d (Conv2D)          (None, 128, 256, 16) 4816        vision_permute[0][0]
# __________________________________________________________________________________________________
# vision_elu (ELU)                (None, 128, 256, 16) 0           vision_conv2d[0][0]
# __________________________________________________________________________________________________
# ...

# %%
# reference: https://stackoverflow.com/questions/56690089/how-to-graph-tf-keras-model-in-tensorflow-2-0
"""
@tf.function
def traceme(x):
    return supercombo(x)


logdir = "log"
writer = tf.summary.create_file_writer(logdir)
tf.summary.trace_on(graph=True, profiler=True)
# Forward pass
traceme([tf.zeros((1, 12, 128, 256)),np.zeros((1,8)),np.zeros((1,512))])
with writer.as_default():
    tf.summary.trace_export(name="model_trace", step=0, profiler_outdir=logdir)
"""
# Out:
# '\n@tf.function\ndef traceme(x):\n    return supercombo(x)\n\n\nlogdir = "log"\nwriter = tf.summary.create_file_writer(logdir)\ntf.summary.trace_on(graph=True, profiler=True)\n# Forward pass\ntraceme([tf.zeros((1, 12, 128, 256)),np.zeros((1,8)),np.zeros((1,512))])\nwith writer.as_default():\n    tf.summary.trace_export(name="model_trace", step=0, profiler_outdir=logdir)\n'

# %%
x_train = [tf.zeros((1, 12, 128, 256)),np.zeros((1,8)),np.zeros((1,512))]
# ['path', 'left_lane', 'right_lane', 'lead', 'long_x', 'long_v', 'long_a', 'meta', 'snpe_pleaser2', 'pose', 'add_3']
y_train = [np.zeros((1,385)), np.zeros((1,386)), np.zeros((1,386)), np.zeros((1,58)), np.zeros((1,200)), np.zeros((1,200)), np.zeros((1,200)), np.zeros((1,4)), np.zeros((1,32)), np.zeros((1,12)), np.zeros((1,512))]

model.compile(
    optimizer='sgd',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'])

logdir = "logs/"

tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

model.fit(x_train,
          y_train,
          batch_size=1,
          epochs=1,
          callbacks=[tensorboard_callback])

# %tensorboard --logdir logs/
# Out:
# Train on 1 samples
# 1/1 [==============================] - 2s 2s/sample
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\miniconda3\envs\carnd\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in on_start(self, model, callbacks, use_samples, verbose, mode)
#     752     try:
# --> 753       yield
#     754       model._successful_loop_finish = True
#
# ~\miniconda3\envs\carnd\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     341                 training_context=training_context,
# --> 342                 total_epochs=epochs)
# ...
